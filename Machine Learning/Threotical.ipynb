# %% [markdown]
# 1St Algoritham: liner regression
#
# Formula : y=mx+c
# Loss Function(MSE) L= (1/n) (y-y)2
# X-independent
# python:
# From sklearn.linear_model import LinearRegression

# %% [markdown]
# 2nd: Logistic Regression: also known as Sigmoid function
#
# Formula: 1 / (1+e-z) ---> e to the power of -z
#
#
# K- Nearest Neighbors (KNN)
# d= sqr of (x1=x2)2
# From sklearn.linear_model import KNeighborsClassifier
# import numpy as np
