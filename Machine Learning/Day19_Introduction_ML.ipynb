# %% [markdown]
# # Pandas - Data collection & Data Manuplation [ data frame , series]
# # Numpy : to convert data into numerical format [ scalar , vector, matric, tensor-DS -nd.array]
# # MatPlotLib : to visualize  type of charts : [ line plot , bar plot , pie , his ,  scatter plot ]
# # seaborn : [ Seaborn works only when matplotlib is installed ]
# # Scikit_Learn - MAchine Learning Framework , [ while installing we use it as  scikit-learn , while using we will call it as sklearn ]
# Code : PNM SS

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# %%
# Define Machine Learning : The ability to learn everything by itself without any external help
# ML has 2 types: 
1. Supervised Learning :

 i) Classification : which is descrete variable is known as classification type. 
            EX:  yes / no , female / male , 
 ii) Regression : Anything which is continous variable is known as regression type.
            EX: Range of numbers (house price b/w 1000- 2000)

   KeyWOrd: Label Data          

2. unsupervised Learning : 

 i) Clustering  : Grouping of data used on some similarity or pattern
            EX: 
 ii) Association : 

 KeyWord: Unlabelled data / pattern / similarity

3. SemiSupervised Learning :

4. RIL [Re-inforcement Learning] : not covering in trainning

# %% [markdown]
# # Regression : Relation (x,y) : Dataset : Features ( COlumn Name , data , label, feature)
#
# # Example : House Price ( Location ,  no of bedrooms , Extra features )
# Number of features ---> Price
# Divide features -----> [ Dependent Variable (y) / Independent Variable (x) ]
# one feature is how it is realted to any other feature
#  x-y

# %% [markdown]
# # Steps of model Creation : CODE : ILC MST CPP E
#
# I - Import Libraries [ PNM SS] : Generally there are 8 libraries
#
#     P-Pandas N- Numpy M-Matplotlib S- Seaborn S-Scikit-Learn
#
#     import pandas as pd
#     import Numpy as np
#     import matplotlib.pyplot as plt
#     import seaborn as sns
#     import sklearn
#
#     3 more imports:
#
#     from sklearn.model_selction import LinearRegression
#     From sklearn.metrics import r2_scorew , MSE , MAE ,  ---> for any regression
#     From sklearn.model_slection import train_test_split
#
#     Note:7 Types of linear regression
#     [ simple Linear(outdated) , Linear Regression , multiple Linear Regression
#     poly Linear Regression , Lasso Regression , Ridge Regression , Elastic Regression ]
#
# L - Load DataSet
#     pd.read_csv("filename with path")
#     pd.read_excel("")
#     pd.read_html("url address")
#
#
# C - Check DataTypes
#
#     df.dtypes
#     df.info()
#
# M - Missing Data Handling [ Exploratory Data Analysis -EDA ]
#
#     df.isnull().sum()
#     df.duplicate().sum()
#     df.describe()
#     outliners
#     plot
#     change datatype
#     rename DAtaType
#     Imputation techniques ( Knn imputer )
#
# S - X,y split (Independent / Dependent )
#
#      X = [[ ]] ---> Dataframe / 2-D / data / column name / feature [ ]
#      y = [ ] ---> Target Variable / Output Variable / Label
#
#      Formula for Linear Regression ---> y = mx + c
#
#
# T - Train - test - split
#     import train-test-split [ From sklearn ]
#
# C - Create , call , Train[fit]
#     lr = LinearRegression()
#     Lr = LogisticRegression()
#     lr.fit_transform()
#
# p - Predict with Model
#     y_pred = lr.predict( X_test )
#
# P - Plot Model
#     ScatterPlot
#     Lineplot
#     title
#     x-label
#     y-axis
#     tigh-layout
#     plt.show()
#
# E - Evaluate The  Model
#
#     mean Squared Error / MSE / classification sore
