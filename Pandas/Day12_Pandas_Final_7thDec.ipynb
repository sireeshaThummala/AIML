# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\sirit\OneDrive\Documents\AI-ML_Training\Pandas\titanic.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail
# Out:
# <bound method NDFrame.tail of      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
len(df.columns)
# Out:
# 12

# %%
df['Name'].head()
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# Name: Name, dtype: object

# %%
df[(df['Age']>30) & (df['Sex']=='female')]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 11            12         1       1
# 15            16         1       2
# 18            19         0       3
# ..           ...       ...     ...
# 862          863         1       1
# 865          866         1       2
# 871          872         1       1
# 879          880         1       1
# 885          886         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
# printing records of people Sex=male and age above 40

# %%
#We need to fetch records whose age is between 30 and 40
df[df['Age'].between(30,40)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 4              5         0       3
# 13            14         0       3
# 18            19         0       3
# ..           ...       ...     ...
# 867          868         0       1
# 872          873         0       1
# 881          882         0       3
# 885          886         0       3
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 13                         Andersson, Mr. Anders Johan    male  39.0      1
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
#changing the column data 'Name' into lowercase

df['Name'].lower()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2512\2737555160.py in ?()
#       1 #changing the column data 'Name' into lowercase
#       2
# ----> 3 df['Name'].lower()
#
# c:\Users\sirit\OneDrive\Documents\AI-ML_Training\.venv\lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'lower'

# %%
#finding datatype of name column
df['Name'].dtype
# Out:
# dtype('O')

# %%
df['Name']=df['Name'].str.lower()

# %%
df['Name']
# Out:
# 0                                braund, mr. owen harris
# 1      cumings, mrs. john bradley (florence briggs th...
# 2                                 heikkinen, miss. laina
# 3           futrelle, mrs. jacques heath (lily may peel)
# 4                               allen, mr. william henry
#                              ...
# 886                                montvila, rev. juozas
# 887                         graham, miss. margaret edith
# 888             johnston, miss. catherine helen "carrie"
# 889                                behr, mr. karl howell
# 890                                  dooley, mr. patrick
# Name: Name, Length: 891, dtype: object

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df['Survived','Pclass',[]]

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#Machine learning Alg will not accept data with missing values
# ML Alg needs to be in numerical format(0,1)
# there should not be any duplicate values in the data set

# %%
# how do i see which rows in side a column does not have data
df[df['Embarked'].isnull()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        icard, miss. amelie
# 829          830         1       1  stone, mrs. george nelson (martha evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 61   female  38.0      0      0  113572  80.0   B28      NaN
# 829  female  62.0      0      0  113572  80.0   B28      NaN

# %%
# Dropping a column / deleting a column [ we refer to a col as axis=1 , we refer to a row as row=0]

df.drop(['Embarked'],axis=1)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              braund, mr. owen harris    male  22.0      1
# 1    cumings, mrs. john bradley (florence briggs th...  female  38.0      1
# 2                               heikkinen, miss. laina  female  26.0      0
# 3         futrelle, mrs. jacques heath (lily may peel)  female  35.0      1
# 4                             allen, mr. william henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.columns
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 df.columns
#
# AttributeError: 'NoneType' object has no attribute 'columns'

# %%
df._copy=df.copy()

# %%
#deleting a column permanently
df=df.drop('Embarked',axis=1 , inplace=True)

# %%
df.columns
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 df.columns()
#
# AttributeError: 'NoneType' object has no attribute 'columns'

# %%
df['Cabin'].isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 df['Cabin'].isnull().sum()
#
# TypeError: 'NoneType' object is not subscriptable

# %%
df.drop("Cabin" , axis=1 , inplace = True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 df.drop("Cabin" , axis=1 , inplace = True)
#
# AttributeError: 'NoneType' object has no attribute 'drop'

# %%
df['Age'].head(15)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 df['Age'].head(15)
#
# TypeError: 'NoneType' object is not subscriptable

# %%
df['Age']=

# %%
# sorting data in ascending order and descending order
df['Age'].sort_values(ascending=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[45], line 2
#       1 # sorting data in ascending order and descending order
# ----> 2 df['Age'].sort_values(ascending=True)
#
# TypeError: 'NoneType' object is not subscriptable

# %%
#finding number of rows missing data inside age column
df['Age'].isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[46], line 2
#       1 #finding number of rows missing data inside age column
# ----> 2 df['Age'].isnull().sum()
#
# TypeError: 'NoneType' object is not subscriptable

# %%
# loading data from various sources as csv, excel, json, clipboard

# loading data from clipboard
df_clip=pd.read_clipboard()

# Loading data from excel file
df_excel=pd.read_excel(r"C:\Users\sirit\OneDrive\Documents\AI-ML_Training\Pandas\SampleExcel.xlsx" , sheet_name='Sheet1')

# Loading data from json file
df_json=pd.read_json(r"C:\Users\sirit\OneDrive\Documents\AI-ML_Training\Pandas\SampleJson.json")

# %%
# loadsing data from database
import sqlite3
conn=sqlite3.connect('sample.db')
df_db=pd.read_sql_query("SELECT * FROM EMPLOYEE" , conn)
df_db.head()

# %%
#export data to various formats like csv, excel, json, clipboard, database
df.to_csv('titanic_output.csv' , index=False)
df.to_excel('titanic_output.xlsx' , index=False)        
df.to_json('titanic_output.json' , orient='records')  # orient='records' to get list of dictionaries format
df.to_clipboard(index=False)
# exporting data to database
df_db.to_sql('EMPLOYEE_OUTPUT' , conn , if_exists='replace' , index=False)

# %%
# For only excel we need to install openpyxl package
! pip install openpyxl
# Saving to excel with multiple sheets
# df.to_excel("New Excel file.xlsx")

# %%
# Saving to excel with multiple sheets
df.to_excel("New Excel file.xlsx")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[47], line 2
#       1 # Saving to excel with multiple sheets
# ----> 2 df.to_excel("New Excel file.xlsx")
#
# AttributeError: 'NoneType' object has no attribute 'to_excel'
