# %%
! pip install -qU pandas
! pip install -qU numpy  #qu-quiet mode
! pip install -qU matplotlib
! pip install -qU seaborn
# Out:
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: Invalid requirement: '#qu-quiet': Expected package name at the start of dependency specifier
#     #qu-quiet
#     ^
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd #
import numpy as np # numerical computing library
import matplotlib.pyplot as plt # plotting library
import seaborn as sns # data visualization library

# %%
# Loding dataset
df=pd.read_csv(r"C:\Users\sirit\OneDrive\Documents\AI-ML_Training\Pandas\titanic.csv")
print(df.head()) # Display first few rows of the dataset
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
len(df.columns)
# Out:
# 12

# %%
# Viewing data from each column [series of data]
df['Age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
df['Name'].count() # count of rows in 'name' column
df['Name'].nunique() # count of unique names in 'name' column           
df['Name'].unique() # array of unique names in 'name' column
df['Name'].value_counts() # count of each unique name in 'name' column
df['Name'].value_counts(normalize=True) # proportion of each unique name in 'name' column
# Out:
# Name
# Dooley, Mr. Patrick                                    0.001122
# Braund, Mr. Owen Harris                                0.001122
# Cumings, Mrs. John Bradley (Florence Briggs Thayer)    0.001122
# Heikkinen, Miss. Laina                                 0.001122
# Futrelle, Mrs. Jacques Heath (Lily May Peel)           0.001122
#                                                          ...
# Hewlett, Mrs. (Mary D Kingcome)                        0.001122
# Vestrom, Miss. Hulda Amanda Adolfina                   0.001122
# Andersson, Mr. Anders Johan                            0.001122
# Saundercock, Mr. William Henry                         0.001122
# Bonnell, Miss. Elizabeth                               0.001122
# Name: proportion, Length: 891, dtype: float64

# %%
df['Name'].nunique() # count of unique names in 'name' column
# Out:
# 891

# %%
df['Name'].unique() # array of unique names in 'name' column
# Out:
# array(['Braund, Mr. Owen Harris',
#        'Cumings, Mrs. John Bradley (Florence Briggs Thayer)',
#        'Heikkinen, Miss. Laina',
#        'Futrelle, Mrs. Jacques Heath (Lily May Peel)',
#        'Allen, Mr. William Henry', 'Moran, Mr. James',
#        'McCarthy, Mr. Timothy J', 'Palsson, Master. Gosta Leonard',
#        'Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)',
#        'Nasser, Mrs. Nicholas (Adele Achem)',
#        'Sandstrom, Miss. Marguerite Rut', 'Bonnell, Miss. Elizabeth',
#        'Saundercock, Mr. William Henry', 'Andersson, Mr. Anders Johan',
#        'Vestrom, Miss. Hulda Amanda Adolfina',
#        'Hewlett, Mrs. (Mary D Kingcome) ', 'Rice, Master. Eugene',
#        'Williams, Mr. Charles Eugene',
#        'Vander Planke, Mrs. Julius (Emelia Maria Vandemoortele)',
#        'Masselmani, Mrs. Fatima', 'Fynney, Mr. Joseph J',
#        'Beesley, Mr. Lawrence', 'McGowan, Miss. Anna "Annie"',
# ...

# %%
df['Survived'].value_counts() # count of each unique values in 'survived' column
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
#finding statistical data  of each column

df['Survived'].mean() # mean is the avg of the values in 'survived' column
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 #finding statistical data  of each column
# ----> 3 df['Survived'].mean() # mean is the avg of the values in 'survived' column
#
# NameError: name 'df' is not defined

# %%
df['Survived'].median() # median is the middle value of the values in 'survived' column
# Out:
# np.float64(0.0)

# %%
df['Survived'].mode() # mode is the most frequently occurring value in 'survived' column
# Out:
# 0    0
# Name: Survived, dtype: int64

# %%
df['Survived'].describe() # statistical summary of 'survived' column
# Out:
# count    891.000000
# mean       0.383838
# std        0.486592
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000
# Name: Survived, dtype: float64

# %%
df.describe() # statistical summary of all numerical columns in the dataframe 
# this command works only for numerical columns
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
len(df.describe()) # describe gives statistical data of each numerical column
# Out:
# 8

# %%
len(df.columns) # number of columns in the dataframe
# Out:
# 12

# %%
# reading data from more than one column

df[['Name','Age','Survived']] # data from data frame 'name', 'age' and 'survived' columns 

# double square bracket means data is from data frame . list of lists. [[]]  2 dimensional
# Out:
#                                                   Name   Age  Survived
# 0                              Braund, Mr. Owen Harris  22.0         0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0         1
# 2                               Heikkinen, Miss. Laina  26.0         1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0         1
# 4                             Allen, Mr. William Henry  35.0         0
# ..                                                 ...   ...       ...
# 886                              Montvila, Rev. Juozas  27.0         0
# 887                       Graham, Miss. Margaret Edith  19.0         1
# 888           Johnston, Miss. Catherine Helen "Carrie"   NaN         0
# 889                              Behr, Mr. Karl Howell  26.0         1
# 890                                Dooley, Mr. Patrick  32.0         0
#
# [891 rows x 3 columns]

# %%
df[['PassengerId','Age','Survived']].mean()
# mean of 'passengerid', 'age' and 'survived' columns
# Out:
# PassengerId    446.000000
# Age             29.699118
# Survived         0.383838
# dtype: float64

# %%
df[['Name','Age','Survived']].head(10) # first 10 rows of 'name', 'age' and 'survived' columns
# Out:
#                                                 Name   Age  Survived
# 0                            Braund, Mr. Owen Harris  22.0         0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0         1
# 2                             Heikkinen, Miss. Laina  26.0         1
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0         1
# 4                           Allen, Mr. William Henry  35.0         0
# 5                                   Moran, Mr. James   NaN         0
# 6                            McCarthy, Mr. Timothy J  54.0         0
# 7                     Palsson, Master. Gosta Leonard   2.0         0
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  27.0         1
# 9                Nasser, Mrs. Nicholas (Adele Achem)  14.0         1

# %%
df[['Name','Age','Survived']].dtypes # data types of 'name', 'age' and 'survived' columns
# Out:
# Name         object
# Age         float64
# Survived      int64
# dtype: object

# %%
df[['Parch','Ticket','Fare','Cabin','Embarked']].dtypes # data types of 'parch', 'ticket', 'fare' and 'cabin' columns
# Out:
# Parch         int64
# Ticket       object
# Fare        float64
# Cabin        object
# Embarked     object
# dtype: object

# %%
# to fetch info from row wise we have 2 commands iloc and loc
df.iloc[700] # first row of the dataframe
# Out:
# PassengerId                                                  701
# Survived                                                       1
# Pclass                                                         1
# Name           Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# Sex                                                       female
# Age                                                         18.0
# SibSp                                                          1
# Parch                                                          0
# Ticket                                                  PC 17757
# Fare                                                     227.525
# Cabin                                                    C62 C64
# Embarked                                                       C
# Name: 700, dtype: object

# %%
df.iloc[700:710] # rows from 700 to 709
# Out:
#      PassengerId  Survived  Pclass  \
# 700          701         1       1
# 701          702         1       1
# 702          703         0       3
# 703          704         0       3
# 704          705         0       3
# 705          706         0       2
# 706          707         1       2
# 707          708         1       1
# 708          709         1       1
# 709          710         1       3
#
#                                                   Name     Sex   Age  SibSp  \
# 700  Astor, Mrs. John Jacob (Madeleine Talmadge Force)  female  18.0      1
# 701                   Silverthorne, Mr. Spencer Victor    male  35.0      0
# 702                              Barbara, Miss. Saiide  female  18.0      0
# 703                              Gallagher, Mr. Martin    male  25.0      0
# 704                            Hansen, Mr. Henrik Juul    male  26.0      1
# 705     Morley, Mr. Henry Samuel ("Mr Henry Marshall")    male  39.0      0
# ...

# %%
# trying to print data from 3rd column to last and 150 to 155

df.iloc[150:156,3:] # rows from 150 to 155 and columns from 3rd to last
# Out:
#                                   Name     Sex   Age  SibSp  Parch  \
# 150         Bateman, Rev. Robert James    male  51.0      0      0
# 151  Pears, Mrs. Thomas (Edith Wearne)  female  22.0      1      0
# 152                   Meo, Mr. Alfonzo    male  55.5      0      0
# 153    van Billiard, Mr. Austin Blyler    male  40.5      0      2
# 154              Olsen, Mr. Ole Martin    male   NaN      0      0
# 155        Williams, Mr. Charles Duane    male  51.0      0      1
#
#           Ticket     Fare Cabin Embarked
# 150  S.O.P. 1166  12.5250   NaN        S
# 151       113776  66.6000    C2        S
# 152   A.5. 11206   8.0500   NaN        S
# 153     A/5. 851  14.5000   NaN        S
# 154    Fa 265302   7.3125   NaN        S
# 155     PC 17597  61.3792   NaN        C

# %%
# [ Rows: Columns ] Whole data science we follow this pattern

# %%
# using  .loc command
df.loc[150:156, 'Name':'Fare'] # rows from 150 to 156 and columns from 'name' to 'fare'
# Out:
#                                   Name     Sex   Age  SibSp  Parch  \
# 150         Bateman, Rev. Robert James    male  51.0      0      0
# 151  Pears, Mrs. Thomas (Edith Wearne)  female  22.0      1      0
# 152                   Meo, Mr. Alfonzo    male  55.5      0      0
# 153    van Billiard, Mr. Austin Blyler    male  40.5      0      2
# 154              Olsen, Mr. Ole Martin    male   NaN      0      0
# 155        Williams, Mr. Charles Duane    male  51.0      0      1
# 156   Gilnagh, Miss. Katherine "Katie"  female  16.0      0      0
#
#           Ticket     Fare
# 150  S.O.P. 1166  12.5250
# 151       113776  66.6000
# 152   A.5. 11206   8.0500
# 153     A/5. 851  14.5000
# 154    Fa 265302   7.3125
# 155     PC 17597  61.3792
# 156        35851   7.7333

# %%
# viewing data about age column
df['Age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
# finding missing values in a given column
# df['Age'].isnull() # returns boolean values True/False for missing values in 'age' column
df['Age'].isnull().sum() # count of missing values in 'age' column
# Out:
# np.int64(177)

# %%
# viewinmg rows with missing values in 'age' column
df[df['Age'].isnull()] # rows where 'age' column has missing values
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
# finding duplicate value in age column
df['Age'].duplicated().sum() # count of duplicate values in 'age' column
# Out:
# np.int64(802)

# %%
df['Age'].value_counts() # count of each unique value in 'age' column
# Out:
# Age
# 24.00    30
# 22.00    27
# 18.00    26
# 28.00    25
# 30.00    25
#          ..
# 24.50     1
# 0.67      1
# 0.42      1
# 34.50     1
# 74.00     1
# Name: count, Length: 88, dtype: int64

# %%
# finding missing values on the df
df.isnull().sum() # count of missing values in each column
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# want to see only those rows of people who's age is above 54
df[df['Age']>54]
# Out:
#      PassengerId  Survived  Pclass  \
# 11            12         1       1
# 15            16         1       2
# 33            34         0       2
# 54            55         0       1
# 94            95         0       3
# 96            97         0       1
# 116          117         0       3
# 152          153         0       3
# 170          171         0       1
# 174          175         0       1
# 195          196         1       1
# 232          233         0       2
# 252          253         0       1
# 268          269         1       1
# 275          276         1       1
# 280          281         0       3
# 326          327         0       3
# 366          367         1       1
# 438          439         0       1
# 456          457         0       1
# 467          468         0       1
# 483          484         1       3
# 487          488         0       1
# 492          493         0       1
# 493          494         0       1
# ...

# %%
# finding rows of people whos age is above 54 and whos gender is Male
# df[df['age']>54] & df['Sex']=='male']

df[(df['Age']>54) & (df['Sex']=='male')]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 33            34         0       2                 Wheadon, Mr. Edward H
# 54            55         0       1        Ostby, Mr. Engelhart Cornelius
# 94            95         0       3                     Coxon, Mr. Daniel
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
# 152          153         0       3                      Meo, Mr. Alfonzo
# 170          171         0       1             Van der hoef, Mr. Wyckoff
# 174          175         0       1               Smith, Mr. James Clinch
# 232          233         0       2             Sjostedt, Mr. Ernst Adolf
# 252          253         0       1             Stead, Mr. William Thomas
# 280          281         0       3                      Duane, Mr. Frank
# 326          327         0       3             Nysveen, Mr. Johan Hansen
# ...

# %%
df[df['Sex']=='male']
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 889          890         1       1           Behr, Mr. Karl Howell  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...
