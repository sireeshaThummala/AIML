# %% [markdown]
# Data Life Cycle:
# Diff Stages / Phases:
#
# 1. Problem Definition : a problem definition should not be more than 2 or 2.5 lines of text
#
# 	# Clarify Objective:
# 	# Choose ML Paradigm:
# 	# Define data & model constraints:
#
# 2. Data Acquisition or data collection : Data collection
#
# 	# Identify Sources
# 	# Collect & Ingest
# 	# Store & version
#
# 3. Data exploration and profiling: once we have data we need to explore (ask customer about the data and collect & convert into diff 	   formats)
#
# 4. Data Cleaning and pre processing: check if there are any garbage , null ,format etc., check data with all possibilities and process it.
#
# 5. Feature Engineering:
#
# 6. Feature Selection or Extraction :
#
# 7. Encoding & Representation:
#
# 8. Train-Test-Split & Validation Strategy:
#
# 9. Model Training:
#
# 10. Model Evaluation:
#
# 11. Model Selection & Finalization:
#
# 12. Model Deployment:
#
# 13. Maintenance & Continuous Learning:
#
# 14. Documentation & Communication :

# %%
# The Package . Library we are going to use for data collection and data Manipulation is known as Pandas

# %%
# installing pandas software
# Please use the following command to install software / library / Package

! pip install pandas

# if you get error in above installation us !pip3 install pandas 
# if it take too long time to install choose different kernel .
# Out:
# ...
#    ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#    ----------------- ---------------------- 5.0/11.3 MB 23.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 10.0/11.3 MB 23.9 MB/s eta 0:00:01
#    ---------------------------------------- 11.3/11.3 MB 22.2 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#    ----------------- ---------------------- 5.8/12.9 MB 27.0 MB/s eta 0:00:01
#    ---------------------------------------  12.8/12.9 MB 30.9 MB/s eta 0:00:01
#    ---------------------------------------- 12.9/12.9 MB 27.0 MB/s eta 0:00:00
# ...
#
#    ---------------------------------------- 0/3 [pytz]
#    ---------------------------------------- 0/3 [pytz]
#    ---------------------------------------- 0/3 [pytz]
#    ---------------------------------------- 0/3 [pytz]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
# ...

# %%
# Step 2: After installing any package we need to import that package .

import pandas as pd

# %%
# find the version number of the  installed packages

pd.__version__

print(f"The installed version of pandas is : {pd.__version__}") # f means a format string
# Out:
# The installed version of pandas is : 2.3.3
