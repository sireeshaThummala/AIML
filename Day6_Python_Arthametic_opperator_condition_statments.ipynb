# %% [markdown]
# # Working with Arthametic Operators
# # BODMAS (Bracket open ,Div , Mul , Add , Sub )

# %%
# Mod operator
5%2
# Out:
# 1

# %%
# working with Comparison Operators

4 > 3 =4
# Out:
#   Cell In[4], line 3
#     4 > 3 =4
#     ^
# SyntaxError: cannot assign to comparison

# %%
3 == 5
# Out:
# False

# %%
4 != 5
# Out:
# True

# %%
# working with Logical Operators
# t & T = T
# T & F = T
# F & F = F
(3 > 2) & (4 > 5)
# Out:
# False

# %%
# Working with Conditional Statements

# In python we have 3 types of conditional statements
# 1 . if
        ## if-else
            ### if-elif-else (elif- else-if)
# 2 . for
# 3 . While

# %%
# Working with if Condition Statements.
# if works only when condition is true.

# if Sync: if (condition) :

if (condition):
    print("condition is true")
else:
    print("condition is false")

# %%
if 4 < 5:
    print("4 is lessthan 5")
# Out:
# 4 is lessthan 5

# %%
if 4 > 5:
    print("4 is less than 5")
else:
    print("4 is not greaterthan 5")
# Out:
# 4 is not greaterthan 5
