# %% [markdown]
# #Functions in Python
#
# # The function is a set of instructions to complete a given job. so all of theses task will execute one by one automatically when we call a function
#
# # to create a function we use : def Keyword , followed by name of the function , followed by () and quolan :
#
# ex: def my_function():
# print("Hello")
#
# # To use a function we need to call it by the name of the function
#
# my_function()

# %%
def my_function():
    print("Hello")

# %%
my_function()

# %%
# creating function to add numbers

def add_numbers(a,b):
    print("the sum is:",a+b)

# %%
# Calling numbers

add_numbers(2,5)

# %%
def any_number_mul(*args):
    return args

# %%
def any_number_add(*args):
    return sum(args)

# %%
any_number_add(2,3)

# %%
# *** Lambda functions : no nmae function : anynonmous functions

# Syn: lambda parameters : expression

# %%
a = lambda x , y : x + y
print(a(5,10))
# Out:
# 15

# %%
b = lambda x ,y : x * y
print(b(2,6))
# Out:
# 12

# %%
# n number of arguments ---> HW
