# %%
# Python is PL

# Pandas ---> this is for data collection and data manipulation : Data structure ( Series and data frame): data frame and series

# Numpy ---> To convert above data into numerical format : Array , metrix ,vector, scalar and tensor : DS : -nd.array

# MatPlotLib ---> this is a library related to visualization of data : ploting graphs : DS : - plot ,subplot , histogram , bar chart , pie chart , scatter plot etc

# Seaborn ---> this is also for visulation mpre beautiful charts / graphs

# Scikit Learn ---> this is for machine learning : ML algorithms : DS : - model , training , testing , evaluation etc
                        # Supervised Learning : regression , classification
                        # Unsupervised Learning : clustering , association

# TensorFlow / Pytorch ---> this is Framework for deep learning : DL algorithms : DS : - neural networks , CNN , RNN , LSTM , GAN etc
# TensorFlow ---> developed by Google (it is a library as well as framework)
# Pytorch ---> developed by Facebook (it is mainly a framework) / Meta 

# Keras ---> this is also a Framework for deep learning : DL algorithms : DS : - neural networks , CNN , RNN , LSTM , GAN etc
# NLP ---> Natural Language Processing : this is for text data processing : DS : - tokenization , stemming , lemmatization , bag of words , TF-IDF , word2vec etc
# CV ---> Computer Vision : this is for image and video data processing : DS : - image classification , object detection , image segmentation , face recognition etc


# LangChain ---> this is a framework for Generative AI and LLMs : DS : - prompt engineering , chatbots , text generation , summarization , translation etc
# (LLM: Large Language Models)

# %%
# We have diff roles in Market:
# Data Analyst ---> mainly work with data collection , data cleaning , data visualization and basic statistical analysis
# Data Scientist ---> mainly work with data collection , data cleaning , data visualization , statistical analysis and
# machine learning model development and evaluation
# Machine Learning Engineer ---> mainly work with machine learning model development , deployment and monitoring
# Deep Learning Engineer ---> mainly work with deep learning model development , deployment and monitoring
# AI Engineer ---> mainly work with AI model development , deployment and monitoring
# NLP Engineer ---> mainly work with NLP model development , deployment and monitoring
# CV Engineer ---> mainly work with CV model development , deployment and monitoring
# Generative AI Engineer ---> mainly work with Generative AI model development , deployment and monitoring
# MLOps Engineer ---> mainly work with machine learning model deployment , monitoring and maintenance
# Data Engineer ---> mainly work with data pipeline development , data warehousing and data lake management
# Big Data Engineer ---> mainly work with big data pipeline development , big data warehousing and big data lake management
# AI Researcher ---> mainly work with AI model research and development

# %%
# We have diff roles in Market:
# Data Engineer: PAndas , Numpy, MatPlotLib,Seaborn

# Data Scientist: Pandas, Numpy, MatPlotLib, Seaborn, Scikit Learn

# ML Engineer: Pandas, Numpy, MatPlotLib, Seaborn, Scikit Learn, TensorFlow/Pytorch

# DL Engineer: Pandas, Numpy, MatPlotLib, Seaborn, Scikit Learn, TensorFlow/Pytorch, Keras

# AI Engineer: Pandas, Numpy, MatPlotLib, Seaborn, Scikit Learn, TensorFlow/Pytorch, Keras, NLP/CV

# NLP Engineer: Pandas, Numpy, MatPlotLib, Seaborn, Scikit Learn, TensorFlow/Pytorch, Keras, NLP

# CV Engineer: Pandas, Numpy, MatPlotLib, Seaborn, Scikit Learn, TensorFlow/Pytorch, Keras, CV

# Generative AI Engineer: Pandas, Numpy, MatPlotLib, Seaborn

# Scikit Learn, TensorFlow/Pytorch, Keras, LangChain

# MLOps Engineer: Pandas, Numpy, MatPlotLib, Seaborn, Scikit Learn, TensorFlow/Pytorch, Keras, Docker, Kubernetes, CI/CD

# AI Researcher: Pandas, Numpy, MatPlotLib, Seaborn,

# Scikit Learn, TensorFlow/Pytorch, Keras, NLP/CV, Research Papers, Advanced Mathematics

# %%
# Data Science Roles:                                       #Data Engineer:            # ML Ops Engineer 
                                                            #Data roles                #LLM Ops Engineer
# MachineLearning Engineer     
# DeepLearning Engineer        
# Generative AI Engineer 
# Computer Vision Engineer   

## Model Deployment Roles: 


#  By the time we start Scikit Learn , prepare yourself for roles or journey into : 
# 1. ML : (ML & DL)
# 2. DL : The ultimate  Data research role
# 3. CV :
# 4. Gen-AI
# 5. Data Engineering 

# Inditify industry of your choice:

# 1. Healthcare
# 2. Finance
# 3. E-commerce
# 4. Retail
# 5. Manufacturing
# 6. Transportation and Logistics
# 7. Telecommunications
# 8. Energy
# 9. Entertainment and Media
# 10. Education
# 11. Agriculture
# 12. Real Estate
# 13. Government and Public Sector
# 14. Marketing and Advertising
# 15. Human Resources
# 16. Cybersecurity
# 17. Sports and Fitness
# 18. Travel and Hospitality


# In That Industry , Start Collecting Major / Medium / Small and Start up company.
# Various Job Roles in thos companies
# Identify the skills required for those roles

# Prepare a couple of Resumes

# Machine Learning Roles , Use one copy of resume
# Deep Learning Roles , Use one copy of resume
# Generative AI Roles , Use one copy of resume
# Data Engineering Roles , Use one copy of resume
